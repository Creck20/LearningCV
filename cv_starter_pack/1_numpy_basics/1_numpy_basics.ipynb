# %% [markdown]
# # 1 Numpy Basics
# ### TODOs
# - [ ] Follow the learning goals in the roadmap
# - [ ] Complete the mini-projects
# - [ ] Write one paragraph about what you learned and one gotcha
# - [ ] Add visuals/plots for before vs after
# - [ ] Record one metric (accuracy, FPS, etc.)

# %%
# Starter code
import numpy as np
import matplotlib.pyplot as plt
import cv2
